# %% [markdown]
# # **Bioinformatics with Jupyter Notebooks for WormBase:**
# ## **Analyses 6 - Ontology Analyses**
# Welcome to the sixth jupyter notebook in the WormBase tutorial series. Over this series of tutorials, we will write code in Python that allows us to retrieve and perform simple analyses with data available on the WormBase sites.
#
# This tutorial will deal with obtaining different ontology information for the given gene input.
# Let's get started!

# %% [markdown]
# As always, we start by importing all the required packages.

# %%
import requests, sys, json
import pandas as pd
pd.set_option('display.max_columns', None) #for ensuring full view of the dataframe generated

# %% [markdown]
# Assign the gene you are looking to obtain the ontology information for to the variable in the cell below.

# %%
gene = 'WBGene00001648'

# %% [markdown]
# ### Gene Ontology

# %% [markdown]
# Gene Ontology gives 3 main sets of information-
# 1) Biological Processes
# 2) Molecular Functions
# 3) Cellular Processes
#
# We will obtain the same information for our gene of interest and extract the data into a dataframe for easy understanding.

# %%
#We first generate the request URL for the gene ontology summary
request = requests.get('http://rest.wormbase.org/rest/field/gene/'+gene+'/gene_ontology_summary')

# %%
#We can obtain the output of the request in the json format
if not request.ok:
  request.raise_for_status()
  sys.exit()
decoded = request.json()
print(json.dumps(decoded, indent = 4))
# Out:
# {
#     "class": "gene",
#     "name": "WBGene00001648",
#     "uri": "rest/field/gene/WBGene00001648/gene_ontology_summary",
#     "gene_ontology_summary": {
#         "data": {
#             "Biological_process": [
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0050829",
#                         "label": "GO:0050829",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0050829",
#                             "label": "defense response to Gram-negative bacterium",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0048681",
#                         "label": "GO:0048681",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0048681",
#                             "label": "negative regulation of axon regeneration",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0032094",
#                         "label": "GO:0032094",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0032094",
#                             "label": "response to food",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0006935",
#                         "label": "GO:0006935",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0006935",
#                             "label": "chemotaxis",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0051301",
#                         "label": "GO:0051301",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0051301",
#                             "label": "cell division",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": {
#                         "occurs_in": [
#                             {
#                                 "id": "WBbt:0003903",
#                                 "label": "ASER",
#                                 "class": "anatomy_term",
#                                 "taxonomy": "all"
#                             }
#                         ]
#                     },
#                     "term_id": {
#                         "id": "GO:0120169",
#                         "label": "GO:0120169",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0120169",
#                             "label": "detection of cold stimulus involved in thermoception",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         },
#                         {
#                             "evidence": {
#                                 "occurs_in": [
#                                     {
#                                         "id": "WBbt:0003903",
#                                         "label": "ASER",
#                                         "class": "anatomy_term",
#                                         "taxonomy": "all"
#                                     }
#                                 ]
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0007188",
#                         "label": "GO:0007188",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0007188",
#                             "label": "adenylate cyclase-modulating G protein-coupled receptor signaling pathway",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0050896",
#                         "label": "GO:0050896",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0050896",
#                             "label": "response to stimulus",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0040012",
#                         "label": "GO:0040012",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0040012",
#                             "label": "regulation of locomotion",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0007165",
#                         "label": "GO:0007165",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0007165",
#                             "label": "signal transduction",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0043051",
#                         "label": "GO:0043051",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0043051",
#                             "label": "regulation of pharyngeal pumping",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0032223",
#                         "label": "GO:0032223",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0032223",
#                             "label": "negative regulation of synaptic transmission, cholinergic",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0007213",
#                         "label": "GO:0007213",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0007213",
#                             "label": "G protein-coupled acetylcholine receptor signaling pathway",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0007049",
#                         "label": "GO:0007049",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0007049",
#                             "label": "cell cycle",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": {
#                         "has_input": [
#                             {
#                                 "id": "WBMol:00003650",
#                                 "label": "aldicarb",
#                                 "class": "molecule",
#                                 "taxonomy": "all"
#                             }
#                         ],
#                         "negatively_regulates": [
#                             {
#                                 "id": "GO:0006936",
#                                 "label": "muscle contraction",
#                                 "class": "go_term",
#                                 "taxonomy": "all"
#                             }
#                         ]
#                     },
#                     "term_id": {
#                         "id": "GO:0042493",
#                         "label": "GO:0042493",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0042493",
#                             "label": "response to drug",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         },
#                         {
#                             "evidence": {
#                                 "has_input": [
#                                     {
#                                         "id": "WBMol:00003650",
#                                         "label": "aldicarb",
#                                         "class": "molecule",
#                                         "taxonomy": "all"
#                                     }
#                                 ],
#                                 "negatively_regulates": [
#                                     {
#                                         "id": "GO:0006936",
#                                         "label": "muscle contraction",
#                                         "class": "go_term",
#                                         "taxonomy": "all"
#                                     }
#                                 ]
#                             }
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0046662",
#                         "label": "GO:0046662",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0046662",
#                             "label": "regulation of oviposition",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0007186",
#                         "label": "GO:0007186",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0007186",
#                             "label": "G protein-coupled receptor signaling pathway",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0060259",
#                         "label": "GO:0060259",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0060259",
#                             "label": "regulation of feeding behavior",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0007212",
#                         "label": "GO:0007212",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0007212",
#                             "label": "dopamine receptor signaling pathway",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 }
#             ],
#             "Molecular_function": [
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0003924",
#                         "label": "GO:0003924",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0003924",
#                             "label": "GTPase activity",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0005525",
#                         "label": "GO:0005525",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0005525",
#                             "label": "GTP binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0019901",
#                         "label": "GO:0019901",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0019901",
#                             "label": "protein kinase binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0016907",
#                         "label": "GO:0016907",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0016907",
#                             "label": "G protein-coupled acetylcholine receptor activity",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0046872",
#                         "label": "GO:0046872",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0046872",
#                             "label": "metal ion binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0043495",
#                         "label": "GO:0043495",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0043495",
#                             "label": "protein-membrane adaptor activity",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0019001",
#                         "label": "GO:0019001",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0019001",
#                             "label": "guanyl nucleotide binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0001664",
#                         "label": "GO:0001664",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0001664",
#                             "label": "G protein-coupled receptor binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0031683",
#                         "label": "GO:0031683",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0031683",
#                             "label": "G-protein beta/gamma-subunit complex binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0000166",
#                         "label": "GO:0000166",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0000166",
#                             "label": "nucleotide binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0005515",
#                         "label": "GO:0005515",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0005515",
#                             "label": "protein binding",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 }
#             ],
#             "Cellular_component": [
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0005834",
#                         "label": "GO:0005834",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0005834",
#                             "label": "heterotrimeric G-protein complex",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0045202",
#                         "label": "GO:0045202",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0045202",
#                             "label": "synapse",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 },
#                 {
#                     "extensions": null,
#                     "term_id": {
#                         "id": "GO:0005938",
#                         "label": "GO:0005938",
#                         "class": "go_term",
#                         "taxonomy": "all"
#                     },
#                     "term_description": [
#                         {
#                             "id": "GO:0005938",
#                             "label": "cell cortex",
#                             "class": "go_term",
#                             "taxonomy": "all"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "description": "gene ontology associations"
#     }
# }

# %% [markdown]
# We output the gene ontology for biological processes, molecular functions, and cellular components each in dataframes which can be used to generate csv files. If you need any more information to be added in your dataframe, just edit the fields in the cells below as per your requirement!

# %%
#Gene Ontology Biological Processes
GO_BP = pd.DataFrame(columns = ['ID', 'Label'])

# %%
biological_processes = request.json()['gene_ontology_summary']['data']['Biological_process']
for i in range(len(biological_processes)):
    GO_BP = GO_BP.append({'ID' : biological_processes[i]['term_description'][0]['id'], 
                          'Label' : biological_processes[i]['term_description'][0]['label']}, ignore_index = True)

# %%
GO_BP
# Out:
#             ID                                              Label
# 0   GO:0050829        defense response to Gram-negative bacterium
# 1   GO:0048681           negative regulation of axon regeneration
# 2   GO:0032094                                   response to food
# 3   GO:0006935                                         chemotaxis
# 4   GO:0051301                                      cell division
# 5   GO:0120169  detection of cold stimulus involved in thermoc...
# 6   GO:0007188  adenylate cyclase-modulating G protein-coupled...
# 7   GO:0050896                               response to stimulus
# 8   GO:0040012                           regulation of locomotion
# 9   GO:0007165                                signal transduction
# 10  GO:0043051                   regulation of pharyngeal pumping
# 11  GO:0032223  negative regulation of synaptic transmission, ...
# 12  GO:0007213  G protein-coupled acetylcholine receptor signa...
# 13  GO:0007049                                         cell cycle
# 14  GO:0042493                                   response to drug
# 15  GO:0046662                          regulation of oviposition
# 16  GO:0007186       G protein-coupled receptor signaling pathway
# 17  GO:0060259                     regulation of feeding behavior
# 18  GO:0007212                dopamine receptor signaling pathway

# %%
#Gene Ontology Molecular Functions
GO_MF = pd.DataFrame(columns = ['ID', 'Label'])

# %%
molecular_functions = request.json()['gene_ontology_summary']['data']['Molecular_function']
for i in range(len(molecular_functions)):
    GO_MF = GO_MF.append({'ID' : molecular_functions[i]['term_description'][0]['id'], 
                          'Label' : molecular_functions[i]['term_description'][0]['label']}, ignore_index = True)

# %%
GO_MF
# Out:
#             ID                                              Label
# 0   GO:0003924                                    GTPase activity
# 1   GO:0005525                                        GTP binding
# 2   GO:0019901                             protein kinase binding
# 3   GO:0016907  G protein-coupled acetylcholine receptor activity
# 4   GO:0046872                                  metal ion binding
# 5   GO:0043495                  protein-membrane adaptor activity
# 6   GO:0019001                          guanyl nucleotide binding
# 7   GO:0001664                 G protein-coupled receptor binding
# 8   GO:0031683       G-protein beta/gamma-subunit complex binding
# 9   GO:0000166                                 nucleotide binding
# 10  GO:0005515                                    protein binding

# %%
#Gene Ontology Cellular Components
GO_CC = pd.DataFrame(columns = ['ID', 'Label'])

# %%
cellular_components = request.json()['gene_ontology_summary']['data']['Cellular_component']
for i in range(len(cellular_components)):
    GO_CC = GO_CC.append({'ID' : cellular_components[i]['term_description'][0]['id'], 
                          'Label' : cellular_components[i]['term_description'][0]['label']}, ignore_index = True)

# %%
GO_CC
# Out:
#            ID                             Label
# 0  GO:0005834  heterotrimeric G-protein complex
# 1  GO:0045202                           synapse
# 2  GO:0005938                       cell cortex

# %% [markdown]
# ### Anatomy Ontology

# %% [markdown]
# Anatomy ontology gives information regarding the tissues in which the queried gene is expressed in.

# %%
#We first generate the request URL for the anatomy ontology
request = requests.get('http://rest.wormbase.org/rest/field/gene/'+gene+'/expressed_in')

# %%
#We can obtain the output of the request in the json format
if not request.ok:
  request.raise_for_status()
  sys.exit()
decoded = request.json()
print(json.dumps(decoded, indent = 4))
# Out:
# {
#     "class": "gene",
#     "name": "WBGene00001648",
#     "uri": "rest/field/gene/WBGene00001648/expressed_in",
#     "expressed_in": {
#         "data": [
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004697",
#                     "label": "head mesodermal cell",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "WBPaper00056826:hmc_biased",
#                             "label": "WBPaper00056826:hmc_biased",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Transcripts that showed significantly lower expression in somatic gonad precursor cells (SGP) vs. head mesodermal cells (hmc).",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00056826",
#                                     "label": "Mathies LD et al., 2019",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "DESeq2, fold change >= 2, FDR <= 0.01.",
#                             "Method_of_isolation": "FACS"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0003679",
#                     "label": "neuron",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1542",
#                             "label": "Expr1542",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "LacZ activity was shown throughout the nervous system at all larva stages and in adults. Virtually all neurons showed goa-1 expression, including HSN. Some non-neuronal types also express goa-1, such as vulva, uterine muscles in the hermaphrodite, the diagonal muscles in the male, most cells of the pharynx, the distal tip cells in the adult hermaphrodite, and the intestinal muscle. GFP construct confirmed this expression pattern."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027567",
#                                     "label": "WBTransgene00027567 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002142",
#                                     "label": "Mendel JE et al., 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "text": {
#                             "id": "WBPaper00030839:Larval_Pan_Neuronal",
#                             "label": "WBPaper00030839:Larval_Pan_Neuronal",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Larval Pan-neural Enriched Genes.",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00030839",
#                                     "label": "Von Stetina SE et al., 2007",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "A two-class unpaired analysis of the data was performed to identify genes that differ by >= 1.5-fold from the reference at a FDR of <1% for the larval pan-neural, embryonic pan-neural, and larval A-class motor neuron datasets.",
#                             "Method_of_isolation": "FACS",
#                             "Method of analysis, Microarray": [
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep1_Set1",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep1_Set1",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep2_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep2_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Pan-neural_Rep3_Set2",
#                                     "label": "WBPaper00030839:Larval_Pan-neural_Rep3_Set2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep3_Set1",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep3_Set1",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Pan-neural_Rep2_Set2",
#                                     "label": "WBPaper00030839:Larval_Pan-neural_Rep2_Set2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep4_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep4_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep4_Set2",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep4_Set2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep2_Set1",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep2_Set1",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep3_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep3_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Pan-neural_Rep1_Set2",
#                                     "label": "WBPaper00030839:Larval_Pan-neural_Rep1_Set2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep5_Set2",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep5_Set2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep1_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep1_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep5_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep5_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "text": {
#                             "id": "WBPaper00031532:Larva_Pan_Neuronal_Enriched",
#                             "label": "WBPaper00031532:Larva_Pan_Neuronal_Enriched",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "WT-Pico Pan-neural Enriched Genes, with genes found multiple times in a single dataset removed (without dups).",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00031532",
#                                     "label": "Watson JD et al., 2008",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "To identify differentially expressed transcripts, normalized intensity values from the pan-neural data sets were compared to a reference (from all larval cells) using Significance Analysis of Microarray software (SAM). A two class unpaired analysis of the data was performed to identify neuron-enriched genes. Pan-neural enriched transcripts in the IVT and WT-Pico-derived data set were defined as 1.5X elevated vs the reference at a False Discovery Rate (FDR) = 3%.",
#                             "Method_of_isolation": "mRNA tagging",
#                             "Method of analysis, Microarray": [
#                                 {
#                                     "id": "WBPaper00031532:Larval_Reference_rep_2",
#                                     "label": "WBPaper00031532:Larval_Reference_rep_2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00031532:Larval_Pan-neural_rep_1",
#                                     "label": "WBPaper00031532:Larval_Pan-neural_rep_1",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00031532:Larval_Pan-neural_rep_4",
#                                     "label": "WBPaper00031532:Larval_Pan-neural_rep_4",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00031532:Larval_Pan-neural_rep_3",
#                                     "label": "WBPaper00031532:Larval_Pan-neural_rep_3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00031532:Larval_Pan-neural_rep_2",
#                                     "label": "WBPaper00031532:Larval_Pan-neural_rep_2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00031532:Larval_Reference_rep_3",
#                                     "label": "WBPaper00031532:Larval_Reference_rep_3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00031532:Larval_Pan-neural_rep_5",
#                                     "label": "WBPaper00031532:Larval_Pan-neural_rep_5",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00031532:Larval_Reference_rep_1",
#                                     "label": "WBPaper00031532:Larval_Reference_rep_1",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "text": {
#                             "id": "WBPaper00048988:neuron_enriched",
#                             "label": "WBPaper00048988:neuron_enriched",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Transcripts enriched in neuronal cells, by comparing fluorescence-activated cell sorted (FACS) neurons with whole worm expression.",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00048988",
#                                     "label": "Kaletsky R et al., 2016",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "DESeq. False discovry rate (FDR) < 0.1.",
#                             "Method_of_isolation": "FACS"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004985",
#                     "label": "SIAVL",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0005017",
#                     "label": "RMGL",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004086",
#                     "label": "PVM",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004444",
#                     "label": "OLLR",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004437",
#                     "label": "OLQVL",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0003666",
#                     "label": "NSM",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "WBPaper00045974:NSM_enriched_totalRNA_tiling",
#                             "label": "WBPaper00045974:NSM_enriched_totalRNA_tiling",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Genes significantly enriched in NSM neurons (isolated by FACS) versus the reference, according to tiling array analysis towards total RNA.",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00045974",
#                                     "label": "Spencer WC et al., 2014",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "A linear model and moderated t-statistic were used to determine differentially expressed genes as implemented by the limma package (v3.21.4). Enriched list contains only genes significantly enriched in the NSM neurons versus the reference <=1.5X and <= 5% FDR.",
#                             "Method_of_isolation": "FACS"
#                         }
#                     },
#                     {
#                         "text": {
#                             "id": "WBPaper00045974:NSM_enriched_DSN-treated_RNAseq",
#                             "label": "WBPaper00045974:NSM_enriched_DSN-treated_RNAseq",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Genes significantly enriched in NSM neurons (isolated by FACS) versus the reference, according to RNAseq analysis towards DSN treated(Duplex-Specific Nuclease method to deplete rRNA sequences) total RNA.",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00045974",
#                                     "label": "Spencer WC et al., 2014",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "Gene expression quantification and differential expression was analyzed using cufflinks v2.2.1. Enriched contains only genes significantly enriched (differentially expressed >= 2.4 fold in total RNA or >= 3.2 fold in DSN treated total RNA) in the NSM neurons versus the reference.",
#                             "Method_of_isolation": "FACS"
#                         }
#                     },
#                     {
#                         "text": {
#                             "id": "WBPaper00045974:NSM_enriched_totalRNA_RNAseq",
#                             "label": "WBPaper00045974:NSM_enriched_totalRNA_RNAseq",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Genes significantly enriched in NSM neurons (isolated by FACS) versus the reference, according to RNAseq analysis towards total RNA.",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00045974",
#                                     "label": "Spencer WC et al., 2014",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "Gene expression quantification and differential expression was analyzed using cufflinks v2.2.1. Enriched contains only genes significantly enriched (differentially expressed >= 2.4 fold in total RNA or >= 3.2 fold in DSN treated total RNA) in the NSM neurons versus the reference.",
#                             "Method_of_isolation": "FACS"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0005319",
#                     "label": "spermatheca",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0005033",
#                     "label": "RMDR",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004438",
#                     "label": "OLQDR",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0005815",
#                     "label": "diagonal muscle",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1542",
#                             "label": "Expr1542",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "LacZ activity was shown throughout the nervous system at all larva stages and in adults. Virtually all neurons showed goa-1 expression, including HSN. Some non-neuronal types also express goa-1, such as vulva, uterine muscles in the hermaphrodite, the diagonal muscles in the male, most cells of the pharynx, the distal tip cells in the adult hermaphrodite, and the intestinal muscle. GFP construct confirmed this expression pattern."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027567",
#                                     "label": "WBTransgene00027567 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002142",
#                                     "label": "Mendel JE et al., 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004431",
#                     "label": "OLQVR",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004971",
#                     "label": "SMDDR",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004094",
#                     "label": "PVCL",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0003938",
#                     "label": "RID",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0006831",
#                     "label": "PVD",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "WBPaper00036375:enriched_in_PVD_OLL",
#                             "label": "WBPaper00036375:enriched_in_PVD_OLL",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Genes with expression enriched in PVD and OLL neurons. Data sets were normalized by RMA and transcripts showing relative PVD enrichment (>= 1.5X) vs. the reference sample were identified by SAM analysis (False Discovery Rate, FDR < 1%).",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00036375",
#                                     "label": "Smith CJ et al., 2010",
# ...
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep3_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep3_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep5_Set2",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep5_Set2",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep1_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep1_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_Reference_Rep5_Set3",
#                                     "label": "WBPaper00030839:Larval_Reference_Rep5_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 },
#                                 {
#                                     "id": "WBPaper00030839:Larval_A-class_Rep3_Set3",
#                                     "label": "WBPaper00030839:Larval_A-class_Rep3_Set3",
#                                     "class": "microarray_experiment",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004088",
#                     "label": "PVDR",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0003926",
#                     "label": "RIML",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0004983",
#                     "label": "SIAVR",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0003832",
#                     "label": "AVM",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1541",
#                             "label": "Expr1541",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "Pharyngeal muscles and HSN stain only with KP#14. Expression neurons include: sensory neurons ALM, AVM, IL1, OLQ, OLL, PHA, PVD, and PVM; motor neurons SMD, HSN, RIM, RMD and RMG; interneurons BDU, CAN, RID, PVC, and SIA; and the pharyngeal neuron NSM. The head mesodermal cell and the spermathecae also express goa-1."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027566",
#                                     "label": "WBTransgene00027566 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002141",
#                                     "label": "Segalat LS, Elkes DA & Kaplan JM, 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0003681",
#                     "label": "pharynx",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1542",
#                             "label": "Expr1542",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "LacZ activity was shown throughout the nervous system at all larva stages and in adults. Virtually all neurons showed goa-1 expression, including HSN. Some non-neuronal types also express goa-1, such as vulva, uterine muscles in the hermaphrodite, the diagonal muscles in the male, most cells of the pharynx, the distal tip cells in the adult hermaphrodite, and the intestinal muscle. GFP construct confirmed this expression pattern."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027567",
#                                     "label": "WBTransgene00027567 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002142",
#                                     "label": "Mendel JE et al., 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0006823",
#                     "label": "AVK",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "WBPaper00055565:AVK_enriched",
#                             "label": "WBPaper00055565:AVK_enriched",
#                             "class": "expression_cluster",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Description": "Transcripts significantly enriched in AVK neurons comparing to all cell types at L1 larva stage.",
#                             "Citation": [
#                                 {
#                                     "id": "WBPaper00055565",
#                                     "label": "Oranth A et al., 2018",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ],
#                             "Algorithm": "edgeR, FDR < 0.001, fold change > 2.",
#                             "Method_of_isolation": "FACS"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "ontology_term": {
#                     "id": "WBbt:0006751",
#                     "label": "head neuron",
#                     "class": "anatomy_term",
#                     "taxonomy": "all"
#                 },
#                 "images": null,
#                 "details": [
#                     {
#                         "text": {
#                             "id": "Expr1542",
#                             "label": "Expr1542",
#                             "class": "expr_pattern",
#                             "taxonomy": "all"
#                         },
#                         "evidence": {
#                             "Type": [
#                                 "Reporter gene"
#                             ],
#                             "Description": [
#                                 "LacZ activity was shown throughout the nervous system at all larva stages and in adults. Virtually all neurons showed goa-1 expression, including HSN. Some non-neuronal types also express goa-1, such as vulva, uterine muscles in the hermaphrodite, the diagonal muscles in the male, most cells of the pharynx, the distal tip cells in the adult hermaphrodite, and the intestinal muscle. GFP construct confirmed this expression pattern."
#                             ],
#                             "Reagents": [
#                                 {
#                                     "id": "WBTransgene00027567",
#                                     "label": "WBTransgene00027567 (transgene)",
#                                     "class": "transgene",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper": [
#                                 {
#                                     "id": "WBPaper00002142",
#                                     "label": "Mendel JE et al., 1995",
#                                     "class": "paper",
#                                     "taxonomy": "c_elegans"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             }
#         ],
#         "description": "the tissue in which the gene is expressed"
#     }
# }

# %% [markdown]
# We output the anatomy ontology in a dataframe which can be used to generate a csv file. If you need any more information to be added in your dataframe, just edit the fields in the cells below as per your requirement!

# %%
#Anatomy Ontology
AO = pd.DataFrame(columns = ['ID', 'Label', 'Evidence'])

# %%
anatomy_terms = request.json()['expressed_in']['data']
for i in range(len(anatomy_terms)):
    AO = AO.append({'ID' : anatomy_terms[i]['ontology_term']['id'], 
                    'Label' : anatomy_terms[i]['ontology_term']['label'],
                    'Evidence': anatomy_terms[i]['details'][0]['evidence']['Description']}, ignore_index = True)

# %%
AO
# Out:
#               ID                 Label  \
# 0   WBbt:0004697  head mesodermal cell
# 1   WBbt:0003679                neuron
# 2   WBbt:0004985                 SIAVL
# 3   WBbt:0005017                  RMGL
# 4   WBbt:0004086                   PVM
# ..           ...                   ...
# 58  WBbt:0004983                 SIAVR
# 59  WBbt:0003832                   AVM
# 60  WBbt:0003681               pharynx
# 61  WBbt:0006823                   AVK
# 62  WBbt:0006751           head neuron
#
#                                              Evidence
# 0   Transcripts that showed significantly lower ex...
# 1   [LacZ activity was shown throughout the nervou...
# 2   [Pharyngeal muscles and HSN stain only with KP...
# 3   [Pharyngeal muscles and HSN stain only with KP...
# 4   [Pharyngeal muscles and HSN stain only with KP...
# ..                                                ...
# 58  [Pharyngeal muscles and HSN stain only with KP...
# 59  [Pharyngeal muscles and HSN stain only with KP...
# 60  [LacZ activity was shown throughout the nervou...
# 61  Transcripts significantly enriched in AVK neur...
# 62  [LacZ activity was shown throughout the nervou...
#
# [63 rows x 3 columns]

# %% [markdown]
# ### Disease Ontology

# %% [markdown]
# Disease ontology gives the information regarding the diseases which the queried gene is assumed or proved to be related to.

# %%
#We first generate the request URL for the human disease ontology
request = requests.get('http://rest.wormbase.org/rest/field/gene/'+gene+'/human_diseases')

# %%
#We can obtain the output of the request in the json format
if not request.ok:
  request.raise_for_status()
  sys.exit()
decoded = request.json()
print(json.dumps(decoded, indent = 4))
# Out:
# {
#     "class": "gene",
#     "name": "WBGene00001648",
#     "uri": "rest/field/gene/WBGene00001648/human_diseases",
#     "human_diseases": {
#         "data": {
#             "potential_model": [
#                 {
#                     "ev": {
#                         "Inferred_automatically": [
#                             "Inferred by orthology to human genes with DO annotation (HGNC:4389)"
#                         ]
#                     },
#                     "id": "DOID:0080450",
#                     "label": "developmental and epileptic encephalopathy 17",
#                     "class": "do_term",
#                     "taxonomy": "all"
#                 }
#             ],
#             "gene": [
#                 "139311"
#             ]
#         },
#         "description": "Diseases related to the gene"
#     }
# }

# %% [markdown]
# We output the human disease ontology in a dataframe which can be used to generate a csv file. If you need any more information to be added in your dataframe, just edit the fields in the cells below as per your requirement!

# %%
#Disease Ontology
DO = pd.DataFrame(columns = ['ID', 'Label', 'Inference Method'])

# %%
disease_terms = request.json()['human_diseases']['data']['potential_model']
for i in range(len(disease_terms)):
    DO = DO.append({'ID' : disease_terms[i]['id'], 
                    'Label' : disease_terms[i]['label'],
                    'Inference Method': disease_terms[i]['ev']}, ignore_index = True)

# %%
DO
# Out:
#              ID                                          Label  \
# 0  DOID:0080450  developmental and epileptic encephalopathy 17
#
#                                     Inference Method
# 0  {'Inferred_automatically': ['Inferred by ortho...

# %% [markdown]
# ### Life Stage Ontology

# %% [markdown]
# Life Stage ontology gives the information regarding the life stages of the organism during which the queried gene is assumed or proved to be active in.

# %%
#We first generate the request URL for the life stage ontology
request = requests.get('http://rest.wormbase.org/rest/field/gene/'+gene+'/fpkm_expression_summary_ls')

# %%
#We can obtain the output of the request in the json format
if not request.ok:
  request.raise_for_status()
  sys.exit()
decoded = request.json()
print(json.dumps(decoded, indent = 4))
# Out:
# {
#     "class": "gene",
#     "name": "WBGene00001648",
#     "uri": "rest/field/gene/WBGene00001648/fpkm_expression_summary_ls",
#     "fpkm_expression_summary_ls": {
#         "data": {
#             "controls": [
#                 {
#                     "control mean": {
#                         "text": 208.9216,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=63 RNASeq FPKM expression values for this gene in this life-stage (Mixed stages) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000002",
#                         "label": "all stages Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control median": {
#                         "text": 222.681,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=63 RNASeq FPKM expression values for this gene in this life-stage (Mixed stages) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control median": {
#                         "text": 82.670898,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=9 RNASeq FPKM expression values for this gene in this life-stage (L2) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000027",
#                         "label": "L2 larva Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control mean": {
#                         "text": 131.0672,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=9 RNASeq FPKM expression values for this gene in this life-stage (L2) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control mean": {
#                         "text": 85.360718,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=51 RNASeq FPKM expression values for this gene in this life-stage (Adult) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000041",
#                         "label": "adult Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control median": {
#                         "text": 86.524597,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=51 RNASeq FPKM expression values for this gene in this life-stage (Adult) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control median": {
#                         "text": 85.947502,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=14 RNASeq FPKM expression values for this gene in this life-stage (L3) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000035",
#                         "label": "L3 larva Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control mean": {
#                         "text": 83.61982,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=14 RNASeq FPKM expression values for this gene in this life-stage (L3) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control median": {
#                         "text": 243.240997,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=83 RNASeq FPKM expression values for this gene in this life-stage (Embryo) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000003",
#                         "label": "embryo Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control mean": {
#                         "text": 268.196594,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=83 RNASeq FPKM expression values for this gene in this life-stage (Embryo) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control median": {
#                         "text": 97.853996,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=2 RNASeq FPKM expression values for this gene in this life-stage (Dauer) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000032",
#                         "label": "dauer larva Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control mean": {
#                         "text": 97.853996,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=2 RNASeq FPKM expression values for this gene in this life-stage (Dauer) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control median": {
#                         "text": 57.135899,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=17 RNASeq FPKM expression values for this gene in this life-stage (L4) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000038",
#                         "label": "L4 larva Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control mean": {
#                         "text": 61.883179,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=17 RNASeq FPKM expression values for this gene in this life-stage (L4) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control mean": {
#                         "text": 239.514694,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=19 RNASeq FPKM expression values for this gene in this life-stage (L1) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "WBls:0000024",
#                         "label": "L1 larva Ce",
#                         "class": "life_stage",
#                         "taxonomy": "all"
#                     },
#                     "control median": {
#                         "text": 119.702003,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=19 RNASeq FPKM expression values for this gene in this life-stage (L1) of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 },
#                 {
#                     "control median": {
#                         "text": 117.309998,
#                         "evidence": {
#                             "comment": [
#                                 "This is the median value of the N=259 RNASeq FPKM expression values for this gene in all life-stages of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     },
#                     "life_stage": {
#                         "id": "total_over_all_stages",
#                         "label": "total over all stages",
#                         "class": "total_over_all_stages",
#                         "taxonomy": null
#                     },
#                     "control mean": {
#                         "text": 185.036896,
#                         "evidence": {
#                             "comment": [
#                                 "This is the mean value of the N=259 RNASeq FPKM expression values for this gene in all life-stages of this species of all samples in the SRA that are wildtype controls that do not appear to have undergone any experimental conditions or treatment that would affect gene expression."
#                             ]
#                         }
#                     }
#                 }
#             ],
#             "by_study": {
#                 "RNASeq_Study.SRP035479": {
#                     "title": "Werner syndrome ortholog and vitamin C (Dallaire 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP035479",
#                         "label": "RNASeq_Study.SRP035479",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment",
#                         "Genotype"
#                     ],
#                     "description": [
#                         "GSE54173: Expression profile by RNA-seq of wild type or Caenorhabditis elegans mutant for the Werner syndrome gene ortholog treated with or without vitamin C"
#                     ]
#                 },
#                 "RNASeq_Study.SRP016006": {
#                     "title": "Comparison of Male and Female (Thomas 2012)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP016006",
#                         "label": "RNASeq_Study.SRP016006",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Sex"
#                     ],
#                     "description": [
#                         "GSE41367: Caenorhabditis sex-specific RNAseq",
#                         "This project defines the transcriptomes of XO (male) and XX (female or mutant pseudo-female) Caenorhabditis nematodes. The data allow the overall composition and sexual regulation of the transcriptome within a single species to be determined. In addition, the five related species studied allow meta-comparisons between them. Because two of the five (C. elegans and C. briggsae) produce a self-fertile XX hermaphrodite, while the XX sex in the remaining three (C. japonica, C. remanei, and C. brenneri) are true females, the data are particularly useful for inferring effects of sexual mode on genome-wide gene expression. Overall Design: L4 larvae and adults were pooled for each sex for five species (C. elegans, C. briggsae, C. japonica, C. brenneri, and C. remanei). Each of these 10 species-sex combinations was replicated three times, for a total of 30 samples."
#                     ]
#                 },
#                 "RNASeq_Study.ERP003471": {
#                     "title": "Larval stages (Engstrm 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.ERP003471",
#                         "label": "RNASeq_Study.ERP003471",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Life stage"
#                     ],
#                     "description": [
#                         "RNA-seq transcript assembly evaluation"
#                     ]
#                 },
#                 "RNASeq_Study.SRP035359": {
#                     "title": "Competence for reprogramming sex (Sorokin 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP035359",
#                         "label": "RNASeq_Study.SRP035359",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Competence for reprogramming sex"
#                     ]
#                 },
#                 "RNASeq_Study.SRP008969": {
#                     "title": "L1 arrest and recovery (Maxwell 2012)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP008969",
#                         "label": "RNASeq_Study.SRP008969",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment"
#                     ],
#                     "description": [
#                         "mRNA-seq of L1 larvae recovering from arrest"
#                     ]
#                 },
#                 "RNASeq_Study.SRP041461": {
#                     "title": "Spermatogenic vs oogenic transcriptomes (Ortiz 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP041461",
#                         "label": "RNASeq_Study.SRP041461",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Tissue"
#                     ],
#                     "description": [
#                         "GSE57109: A new dataset of spermatogenic vs oogenic transcriptomes in the nematod C. elegans"
#                     ]
#                 },
#                 "RNASeq_Study.SRP045110": {
#                     "title": "Asymmetric Transcript Discovery (Nishimura 2015)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP045110",
#                         "label": "RNASeq_Study.SRP045110",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Blastomere-specific transcriptome sequencing reveals a determinant of anterior specification in C. elegans"
#                     ]
#                 },
#                 "RNASeq_Study.SRP049412": {
#                     "title": "C. elegans Y-box-binding proteins (Arnold 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP049412",
#                         "label": "RNASeq_Study.SRP049412",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Defining soma-specific/enriched and germline-specific/enriched transcripts"
#                     ]
#                 },
#                 "RNASeq_Study.SRP042619": {
#                     "title": "Oocytetoembryo transition (Stoeckius 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP042619",
#                         "label": "RNASeq_Study.SRP042619",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Global characterization of the oocyte-to-embryo transition in C. elegans uncovers a novel mRNA turnover mechanism"
#                     ]
#                 },
#                 "RNASeq_Study.SRP018867": {
#                     "title": "Gene repression by EMR-1 and LEM-2 (Gonzlez-Aguilera 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP018867",
#                         "label": "RNASeq_Study.SRP018867",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Genotype"
#                     ],
#                     "description": [
#                         "GSE44682: Next generation sequencing facilitates quantitative analysis of Caenorhabditis elegans N2 wild type, emr-1(gk119), lem-2(tm1582) and emr-1(RNAi) lem-2(tm1582) transcriptomes."
#                     ]
#                 },
#                 "RNASeq_Study.SRP000401": {
#                     "title": "modENCODE Integrative analysis (Gerstein 2010)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP000401",
#                         "label": "RNASeq_Study.SRP000401",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment",
#                         "Tissue",
#                         "Life stage",
#                         "Sex"
#                     ],
#                     "description": [
#                         "Deep sequencing of the Caenorhabditis elegans transcriptome using RNA isolated from various developmental stages under various experimental conditions RW0001",
#                         "The goal of this study, started as a part of the modENCODE project, is to detect and characterize previously unannotated transcripts of the C. elegans genome."
#                     ]
#                 },
#                 "RNASeq_Study.SRP003783": {
#                     "title": "Comparison of RNASeq protocols (Lamm 2011)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP003783",
#                         "label": "RNASeq_Study.SRP003783",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment",
#                         "Life stage",
#                         "Genotype"
#                     ],
#                     "description": [
#                         "Multimodal RNA-seq using single-strand, double-strand, and circligase-based capture yields a refined and extended description of the C. elegans transcriptome"
#                     ]
#                 },
#                 "RNASeq_Study.SRP021083": {
#                     "title": "Mitochondrial inhibitor rotenone (Schmeisser 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP021083",
#                         "label": "RNASeq_Study.SRP021083",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment"
#                     ],
#                     "description": [
#                         "GSE46051: Deep sequencing of endogenous mRNA from Caenorhabditis elegans in the presence and absence of rotenone at 4 different time points"
#                     ]
#                 },
#                 "RNASeq_Study.SRP035507": {
#                     "title": "The zoonotic hookworm Ancylostoma ceylanicum (Schwarz 2015)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP035507",
#                         "label": "RNASeq_Study.SRP035507",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Caenorhabditis elegans transcriptome, in response to albendazole"
#                     ]
#                 },
#                 "RNASeq_Study.SRP031831": {
#                     "title": "A-to-I RNA Editing (Washburn 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP031831",
#                         "label": "RNASeq_Study.SRP031831",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "The dsRBP and inactive editor, ADR-1, utilizes dsRNA binding to regulate A-to-I RNA editing across the C. elegans transcriptome"
#                     ]
#                 },
#                 "RNASeq_Study.SRP021462": {
#                     "title": "Effect of low-dose arsenite (Schmeisser 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP021462",
#                         "label": "RNASeq_Study.SRP021462",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment"
#                     ],
#                     "description": [
#                         "GSE46257: Deep sequencing of endogenous mRNA from Caenorhabditis elegans in the presence and absence of arsenite"
#                     ]
#                 },
#                 "RNASeq_Study.SRP030526": {
#                     "title": "Transcription error rate measurement (Gout 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP030526",
#                         "label": "RNASeq_Study.SRP030526",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Strain"
#                     ],
#                     "description": [
#                         "Caenorhabditis elegans Transcriptome or Gene expression"
#                     ]
#                 },
#                 "RNASeq_Study.SRP003492": {
#                     "title": "Larval stages (Mortazavi 2010)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP003492",
#                         "label": "RNASeq_Study.SRP003492",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Life stage"
#                     ],
#                     "description": [
#                         "Caenorhabditis angaria genome sequencing project"
#                     ]
#                 },
#                 "RNASeq_Study.SRP017621": {
#                     "title": "Effect of mab-5 mutants (Tamayo 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP017621",
#                         "label": "RNASeq_Study.SRP017621",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Strain"
#                     ],
#                     "description": [
#                         "Using RNA-seq to identify transcriptional targets of MAB-5 in C. elegans"
#                     ]
#                 },
#                 "RNASeq_Study.SRP040623": {
#                     "title": "Expression in a prg-1 mutant (Wang 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP040623",
#                         "label": "RNASeq_Study.SRP040623",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Life stage"
#                     ],
#                     "description": [
#                         "GSE56271: The expression mRNAs after prg-1 mutation"
#                     ]
#                 },
#                 "RNASeq_Study.SRP015918": {
#                     "title": "Effect of PMK-1 on heat stress response (Mertenskoetter 2012)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP015918",
#                         "label": "RNASeq_Study.SRP015918",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Strain"
#                     ],
#                     "description": [
#                         "GSE41205: Influence of p38 MAPK (PMK-1) on the heat stress response of C. elegans"
#                     ]
#                 },
#                 "RNASeq_Study.SRP018033": {
#                     "title": "Effect of Nitrogen Oxide (Gusarov 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP018033",
#                         "label": "RNASeq_Study.SRP018033",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment"
#                     ],
#                     "description": [
#                         "GSE43614: NO-mediated transcriptional response in C. elegans"
#                     ]
#                 },
#                 "RNASeq_Study.SRP011038": {
#                     "title": "daf-2 mutant vs N2 (Zarse 2012)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP011038",
#                         "label": "RNASeq_Study.SRP011038",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Strain"
#                     ],
#                     "description": [
#                         "Impaired Insulin-/IGF1-Signaling Extends Life Span by Promoting Mitochondrial L-Proline Catabolism to Induce a Transient ROS-Signal"
#                     ]
#                 },
#                 "RNASeq_Study.SRP029448": {
#                     "title": "The evolutionary history of the endoderm germ layer (Hashimshony 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP029448",
#                         "label": "RNASeq_Study.SRP029448",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Spatiotemporal embryonic transcriptomics reveals the evolutionary history of the endoderm germ layer"
#                     ]
#                 },
#                 "RNASeq_Study.SRP005562": {
#                     "title": "Effect of EGO-1 in development (Maniar 2011)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP005562",
#                         "label": "RNASeq_Study.SRP005562",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Life stage",
#                         "Genotype"
#                     ],
#                     "description": [
#                         "mRNA sequencing from ego-1(om84) and control L3, L4, and adult C. elegans hermaphrodites"
#                     ]
#                 },
#                 "RNASeq_Study.SRP000253": {
#                     "title": "L1 larva transcriptome (Shin 2008)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP000253",
#                         "label": "RNASeq_Study.SRP000253",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Transcriptome analysis for Caenorhabditis elegans based on novel expressed sequence tags"
#                     ]
#                 },
#                 "RNASeq_Study.SRP074511": {
#                     "title": "Tubulins in sensory neurons (Lockhead 2016)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP074511",
#                         "label": "RNASeq_Study.SRP074511",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Single-cell RNA-seq of PLM, AFD, and ASER sensory neurons of Caenorhabditis elegans."
#                     ]
#                 },
#                 "RNASeq_Study.SRP015332": {
#                     "title": "Multiple insert sizes (Smith 2012)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP015332",
#                         "label": "RNASeq_Study.SRP015332",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment"
#                     ],
#                     "description": [
#                         "GSE40507: Multiple insert size paired-end sequencing for deconvolution of complex transcriptomes"
#                     ]
#                 },
#                 "RNASeq_Study.SRP040269": {
#                     "title": "Effect of nhr-62 and eat-2 mutants (Heestand 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP040269",
#                         "label": "RNASeq_Study.SRP040269",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Genotype"
#                     ],
#                     "description": [
#                         "GSE55988: mRNA profile in DR-related mutants"
#                     ]
#                 },
#                 "RNASeq_Study.SRP015688": {
#                     "title": "Linker cell expression (Schwartz 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP015688",
#                         "label": "RNASeq_Study.SRP015688",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment",
#                         "Tissue",
#                         "Life stage"
#                     ],
#                     "description": [
#                         "C. elegans linker cell transcriptome"
#                     ]
#                 },
#                 "RNASeq_Study.SRP041095": {
#                     "title": "Alternative splice (Norris 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP041095",
#                         "label": "RNASeq_Study.SRP041095",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Caenorhabditis elegans Transcriptome or Gene expression"
#                     ]
#                 },
#                 "RNASeq_Study.SRP043990": {
#                     "title": "GLD-2 and GLD-4 promote general gene expression (Nousch 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP043990",
#                         "label": "RNASeq_Study.SRP043990",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "The cytoplasmic poly(A) polymerases GLD-2 and GLD-4 promote general gene expression via distinct mechanisms"
#                     ]
#                 },
#                 "RNASeq_Study.SRP017908": {
#                     "title": "SWI/SNF regulates DAF-16/FOXO genes (Riedel 2012)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP017908",
#                         "label": "RNASeq_Study.SRP017908",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Genotype"
#                     ],
#                     "description": [
#                         "DAF-16/FOXO uses SWI/SNF to regulate transcription."
#                     ]
#                 },
#                 "RNASeq_Study.SRP014581": {
#                     "title": "Sperm transcriptome (Ma 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP014581",
#                         "label": "RNASeq_Study.SRP014581",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Caenorhabditis elegans sperm mRNAome sequencing"
#                     ]
#                 },
#                 "RNASeq_Study.SRP037555": {
#                     "title": "D-Glucosamine supplementation (Wiemer 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP037555",
#                         "label": "RNASeq_Study.SRP037555",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "RNA-seq of C.elegans and M.musculus in the presence and absence of D-Glucosamine (GlcN)"
#                     ]
#                 },
#                 "RNASeq_Study.SRP058023": {
#                     "title": "Comparative genomics of Steinernema (Dillman 2015)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP058023",
#                         "label": "RNASeq_Study.SRP058023",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Comparative genomics of Steinernema reveals deeply conserved gene regulatory networks"
#                     ]
#                 },
#                 "RNASeq_Study.SRP051404": {
#                     "title": "Responses to pathogenic Bacillus thuringiensis (Yang 2015)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP051404",
#                         "label": "RNASeq_Study.SRP051404",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "Overlapping and unique signatures in the proteomic and transcriptomic responses of the nematode Caenorhabditis elegans towards pathogenic Bacillus thuringiensis"
#                     ]
#                 },
#                 "RNASeq_Study.SRP034667": {
#                     "title": "Sex-Biased Gene Expression (Albritton 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP034667",
#                         "label": "RNASeq_Study.SRP034667",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Sex"
#                     ],
#                     "description": [
#                         "GSE53144: Male and Female DNA and RNA sequencing in several nematode species",
#                         "Male and Female DNA and RNA sequencing in several nematode species"
#                     ]
#                 },
#                 "RNASeq_Study.SRP057263": {
#                     "title": "CSR-1 and P granules (Campbell 2015)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP057263",
#                         "label": "RNASeq_Study.SRP057263",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "CSR-1 and P granules suppress sperm-specific transcription in the C. elegans germline"
#                     ]
#                 },
#                 "RNASeq_Study.SRP038704": {
#                     "title": "WT and blmp-1 L3 larvae (Horn 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP038704",
#                         "label": "RNASeq_Study.SRP038704",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Genotype"
#                     ],
#                     "description": [
#                         "GSE55225: RNA-seq analysis of WT and blmp-1(tm548) mutant L3 larvae"
#                     ]
#                 },
#                 "RNASeq_Study.SRP028602": {
#                     "title": "Effect of nicotinic acid and methylnicotinamide (Schmeisser 2013)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP028602",
#                         "label": "RNASeq_Study.SRP028602",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment"
#                     ],
#                     "description": [
#                         "GSE49662: Deep sequencing of endogenous mRNA from Caenorhabditis elegans in the presence and absence of 1-methylnicotinamide (MNA) and nicotinic acid (NA)"
#                     ]
#                 },
#                 "RNASeq_Study.SRP034522": {
#                     "title": "Expression across life stages (Grn 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP034522",
#                         "label": "RNASeq_Study.SRP034522",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Life stage"
#                     ],
#                     "description": [
#                         "GSE53359: Conservation of mRNA and protein expression during development of C. elegans"
#                     ]
#                 },
#                 "RNASeq_Study.SRP047464": {
#                     "title": "RtcB RNA ligase (Kosmaczewski 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP047464",
#                         "label": "RNASeq_Study.SRP047464",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "The RtcB RNA ligase is an essential component of the metazoan unfolded protein response."
#                     ]
#                 },
#                 "RNASeq_Study.SRP044752": {
#                     "title": "SPK-1 in alternate splicing (Miki 2014)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP044752",
#                         "label": "RNASeq_Study.SRP044752",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [
#                         "Treatment"
#                     ],
#                     "description": [
#                         "GSE59705: The role of SPK-1 in alternative splicing regulation in C. elegans"
#                     ]
#                 },
#                 "RNASeq_Study.SRP010374": {
#                     "title": "Ribosome profiling (Stadler 2011)",
#                     "tag": {
#                         "id": "RNASeq_Study.SRP010374",
#                         "label": "RNASeq_Study.SRP010374",
#                         "class": "analysis",
#                         "taxonomy": "all"
#                     },
#                     "indep_variable": [],
#                     "description": [
#                         "In the universal genetic code, most amino acids can be encoded by multiple trinucleotide codons, and the choice among available codons can influence position-specific translation elongation rates. By using sequence-based ribosome profiling, we obtained transcriptome-wide profiles of in vivo ribosome occupancy as a function of codon identity in Caenorhabditis elegans and human cells. Particularly striking in these profiles was a universal trend of higher ribosome occupancy for codons translated via G:U wobble base-pairing compared with synonymous codons that pair with the same tRNA family using G:C base-pairing. These data support a model in which ribosomal translocation is slowed at wobble codon positions."
#                     ]
#                 }
#             },
#             "table": {
#                 "fpkm": {
#                     "data": [
#                         {
#                             "value": 105.223999,
#                             "life_stage": {
#                                 "id": "WBls:0000674",
#                                 "label": "10-days post-L4 adult hermaphrodite Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP021083",
#                                 "label": "RNASeq_Study.SRP021083",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX265369"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000674.Hermaphrodite.WBbt:0007833.SRP021083.SRX265369",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000674.Hermaphrodite.WBbt:0007833.SRP021083.SRX265369",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 153.246994,
#                             "life_stage": {
#                                 "id": "WBls:0000052",
#                                 "label": "post dauer L3 stage Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX103278"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00004309.WBls:0000052.Hermaphrodite.WBbt:0007833.SRP000401.SRX103278",
#                                 "label": "RNASeq.elegans.WBStrain00004309.WBls:0000052.Hermaphrodite.WBbt:0007833.SRP000401.SRX103278",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 62.283699,
#                             "life_stage": {
#                                 "id": "WBls:0000013",
#                                 "label": "enclosing embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX099986"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000013.Hermaphrodite.WBbt:0007833.SRP000401.SRX099986",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000013.Hermaphrodite.WBbt:0007833.SRP000401.SRX099986",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 91.226601,
#                             "life_stage": {
#                                 "id": "WBls:0000038",
#                                 "label": "L4 larva Ce",
# ...
#                         },
#                         {
#                             "value": 195.270996,
#                             "life_stage": {
#                                 "id": "WBls:0000010",
#                                 "label": "gastrulating embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX085218"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000010.Hermaphrodite.WBbt:0007833.SRP000401.SRX085218",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000010.Hermaphrodite.WBbt:0007833.SRP000401.SRX085218",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 186.735992,
#                             "life_stage": {
#                                 "id": "WBls:0000031",
#                                 "label": "L2d-dauer molt Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX103274"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00004309.WBls:0000031.Hermaphrodite.WBbt:0007833.SRP000401.SRX103274",
#                                 "label": "RNASeq.elegans.WBStrain00004309.WBls:0000031.Hermaphrodite.WBbt:0007833.SRP000401.SRX103274",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 104.266998,
#                             "life_stage": {
#                                 "id": "WBls:0000035",
#                                 "label": "L3 larva Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP038704",
#                                 "label": "RNASeq_Study.SRP038704",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX474209"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00047070.WBls:0000035.Hermaphrodite.WBbt:0007833.SRP038704.SRX474209",
#                                 "label": "RNASeq.elegans.WBStrain00047070.WBls:0000035.Hermaphrodite.WBbt:0007833.SRP038704.SRX474209",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 182.710999,
#                             "life_stage": {
#                                 "id": "WBls:0000014",
#                                 "label": "late cleavage stage embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX1022607"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000014.Hermaphrodite.WBbt:0007833.SRP000401.SRX1022607",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000014.Hermaphrodite.WBbt:0007833.SRP000401.SRX1022607",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 139.412003,
#                             "life_stage": {
#                                 "id": "WBls:0000024",
#                                 "label": "L1 larva Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP017621",
#                                 "label": "RNASeq_Study.SRP017621",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX212105"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00024165.WBls:0000024.Hermaphrodite.WBbt:0007833.SRP017621.SRX212105",
#                                 "label": "RNASeq.elegans.WBStrain00024165.WBls:0000024.Hermaphrodite.WBbt:0007833.SRP017621.SRX212105",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 143.281006,
#                             "life_stage": {
#                                 "id": "WBls:0000004",
#                                 "label": "proliferating embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX103649"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000004.Hermaphrodite.WBbt:0007833.SRP000401.SRX103649",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000004.Hermaphrodite.WBbt:0007833.SRP000401.SRX103649",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 338.809998,
#                             "life_stage": {
#                                 "id": "WBls:0000004",
#                                 "label": "proliferating embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX004866"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000004.Hermaphrodite.WBbt:0007833.SRP000401.SRX004866",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000004.Hermaphrodite.WBbt:0007833.SRP000401.SRX004866",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 103.457001,
#                             "life_stage": {
#                                 "id": "WBls:0000063",
#                                 "label": "newly molted young adult hermaphrodite Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP040269",
#                                 "label": "RNASeq_Study.SRP040269",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX494547"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000063.Hermaphrodite.WBbt:0007833.SRP040269.SRX494547",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000063.Hermaphrodite.WBbt:0007833.SRP040269.SRX494547",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 4.02208,
#                             "life_stage": {
#                                 "id": "WBls:0000002",
#                                 "label": "all stages Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP030526",
#                                 "label": "RNASeq_Study.SRP030526",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX362868"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00036497.WBls:0000002.Hermaphrodite.WBbt:0007833.SRP030526.SRX362868",
#                                 "label": "RNASeq.elegans.WBStrain00036497.WBls:0000002.Hermaphrodite.WBbt:0007833.SRP030526.SRX362868",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 229.820007,
#                             "life_stage": {
#                                 "id": "WBls:0000021",
#                                 "label": "fully-elongated embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX047446"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000021.Hermaphrodite.WBbt:0007833.SRP000401.SRX047446",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000021.Hermaphrodite.WBbt:0007833.SRP000401.SRX047446",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 50.054298,
#                             "life_stage": {
#                                 "id": "WBls:0000063",
#                                 "label": "newly molted young adult hermaphrodite Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP035359",
#                                 "label": "RNASeq_Study.SRP035359",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX426026"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00022651.WBls:0000063.Hermaphrodite.WBbt:0007833.SRP035359.SRX426026",
#                                 "label": "RNASeq.elegans.WBStrain00022651.WBls:0000063.Hermaphrodite.WBbt:0007833.SRP035359.SRX426026",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 60.709,
#                             "life_stage": {
#                                 "id": "WBls:0000006",
#                                 "label": "1-cell embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP042619",
#                                 "label": "RNASeq_Study.SRP042619",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX559706"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000006.Hermaphrodite.WBbt:0007833.SRP042619.SRX559706",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000006.Hermaphrodite.WBbt:0007833.SRP042619.SRX559706",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         },
#                         {
#                             "value": 489.190002,
#                             "life_stage": {
#                                 "id": "WBls:0000020",
#                                 "label": "3-fold embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "project_info": {
#                                 "id": "RNASeq_Study.SRP000401",
#                                 "label": "RNASeq_Study.SRP000401",
#                                 "class": "analysis",
#                                 "taxonomy": "all",
#                                 "experiment": "SRX099973"
#                             },
#                             "label": {
#                                 "id": "RNASeq.elegans.WBStrain00000001.WBls:0000020.Hermaphrodite.WBbt:0007833.SRP000401.SRX099973",
#                                 "label": "RNASeq.elegans.WBStrain00000001.WBls:0000020.Hermaphrodite.WBbt:0007833.SRP000401.SRX099973",
#                                 "class": "analysis",
#                                 "taxonomy": "all"
#                             }
#                         }
#                     ]
#                 }
#             }
#         },
#         "description": "Fragments Per Kilobase of transcript per Million mapped reads (FPKM) expression data"
#     }
# }

# %% [markdown]
# We output the life stage ontology in a dataframe which can be used to generate a csv file. If you need any more information to be added in your dataframe, just edit the fields in the cells below as per your requirement!

# %%
#Life Stage Ontology
LSO = pd.DataFrame(columns = ['ID', 'Label'])

# %%
life_stages = request.json()['fpkm_expression_summary_ls']['data']['controls']
for i in range(len(life_stages)):
    LSO = LSO.append({'ID' : life_stages[i]['life_stage']['id'], 
                    'Label' : life_stages[i]['life_stage']['label']}, ignore_index = True)

# %%
LSO
# Out:
#                       ID                  Label
# 0           WBls:0000002          all stages Ce
# 1           WBls:0000027            L2 larva Ce
# 2           WBls:0000041               adult Ce
# 3           WBls:0000035            L3 larva Ce
# 4           WBls:0000003              embryo Ce
# 5           WBls:0000032         dauer larva Ce
# 6           WBls:0000038            L4 larva Ce
# 7           WBls:0000024            L1 larva Ce
# 8  total_over_all_stages  total over all stages

# %% [markdown]
# ### Phenotype Ontology

# %% [markdown]
# Phenotype ontology gives the information regarding the phenotypes whose expression the queried gene is assumed or proved to be responsible for.

# %%
#We first generate the request URL for the life stage ontology
request = requests.get('http://rest.wormbase.org/rest/field/gene/'+gene+'/phenotype')

# %%
#We can obtain the output of the request in the json format
if not request.ok:
  request.raise_for_status()
  sys.exit()
decoded = request.json()
print(json.dumps(decoded, indent = 4))
# Out:
# {
#     "class": "gene",
#     "name": "WBGene00001648",
#     "uri": "rest/field/gene/WBGene00001648/phenotype",
#     "phenotype": {
#         "data": [
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000062",
#                     "label": "lethal",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089556",
#                             "label": "n499",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Person_evidence": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson261",
#                                     "label": "Jonathan Hodgkin",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Remark": [
#                                 "recessive lethal"
#                             ],
#                             "Recessive": "",
#                             "Ease_of_scoring": {
#                                 "taxonomy": "all",
#                                 "class": "tag",
#                                 "label": "Es3 easy to score",
#                                 "id": "Es3 easy to score"
#                             }
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0002292",
#                     "label": "body posture amplitude decreased",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00242615",
#                             "label": "sa734",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson2987",
#                                     "label": "Chris Grove",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00043908",
#                                     "taxonomy": "all",
#                                     "label": "Yemini E, Jucikas T, Grundy LJ, Brown AE & Schafer WR, 2013"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": [
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "GO:0006935",
#                                 "label": "chemotaxis",
#                                 "class": "go_term",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "go-term",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "GO:0006935_go-term_abnormal"
#                     }
#                 ],
#                 "phenotype": {
#                     "id": "WBPhenotype:0001462",
#                     "label": "sodium chloride chemotaxis variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar02148998",
#                             "label": "pe771",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson10274",
#                                     "label": "Hayao Ohno",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00053017",
#                                     "taxonomy": "all",
#                                     "label": "Ohno H, Sakai N, Adachi T & Iino Y, 2017"
#                                 }
#                             ],
#                             "Remark": [
#                                 "Animals are attracted to high salt concentrations (Figure 4, S4)"
#                             ],
#                             "Affected_by_molecule": [
#                                 {
#                                     "id": "WBMol:00003571",
#                                     "label": "Sodium Chloride",
#                                     "class": "molecule",
#                                     "taxonomy": "all"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0002345",
#                     "label": "forward locomotion variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00242615",
#                             "label": "sa734",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson2987",
#                                     "label": "Chris Grove",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00043908",
#                                     "taxonomy": "all",
#                                     "label": "Yemini E, Jucikas T, Grundy LJ, Brown AE & Schafer WR, 2013"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0002295",
#                     "label": "body posture wavelength decreased",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00242615",
#                             "label": "sa734",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson2987",
#                                     "label": "Chris Grove",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00043908",
#                                     "taxonomy": "all",
#                                     "label": "Yemini E, Jucikas T, Grundy LJ, Brown AE & Schafer WR, 2013"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000641",
#                     "label": "activity level variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089452",
#                             "label": "n363",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00004721",
#                                     "taxonomy": "all",
#                                     "label": "van Swinderen B et al., 2001"
#                                 }
#                             ],
#                             "Remark": [
#                                 "Dispersal index in the absence of anesthetic ~0.95 was  increased compared to N2 ~0.90."
#                             ],
#                             "Treatment": "Dispersal assay as reported in Crowder et al.1996; van Swinderen et al. 1997."
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000644",
#                     "label": "paralyzed",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089556",
#                             "label": "n499",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson48",
#                                     "label": "Carol Bastiani",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00000914",
#                                     "taxonomy": "all",
#                                     "label": "Park EC & Horvitz HR, 1986"
#                                 }
#                             ],
#                             "Remark": [
#                                 "move only occasionally"
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000643",
#                     "label": "locomotion variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089556",
#                             "label": "n499",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Person_evidence": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson261",
#                                     "label": "Jonathan Hodgkin",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Remark": [
#                                 "n499/+is uncoordinated, paralysed"
#                             ],
#                             "Dominant": "",
#                             "Ease_of_scoring": {
#                                 "taxonomy": "all",
#                                 "class": "tag",
#                                 "label": "Es3 easy to score",
#                                 "id": "Es3 easy to score"
#                             }
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000004",
#                     "label": "constitutive egg laying",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00248936",
#                             "label": "sy192",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Person_evidence": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson261",
#                                     "label": "Jonathan Hodgkin",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000546",
#                     "label": "early eggs laid",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089452",
#                             "label": "n363",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00004721",
#                                     "taxonomy": "all",
#                                     "label": "van Swinderen B et al., 2001"
#                                 }
#                             ],
#                             "Recessive": "",
#                             "Penetrance": "100% eggs laid are early (e.g. 8 or fewer cells.)(n=20)",
#                             "Variation_effect": [
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Null",
#                                     "id": "Null"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Curator_confirmed",
#                                     "id": "Curator_confirmed"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Paper_evidence",
#                                     "id": "Paper_evidence"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0001716",
#                     "label": "forward point velocity variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00242615",
#                             "label": "sa734",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson2987",
#                                     "label": "Chris Grove",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00043908",
#                                     "taxonomy": "all",
#                                     "label": "Yemini E, Jucikas T, Grundy LJ, Brown AE & Schafer WR, 2013"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0001414",
#                     "label": "male mating defective",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00248936",
#                             "label": "sy192",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Person_evidence": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson261",
#                                     "label": "Jonathan Hodgkin",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000546",
#                     "label": "early eggs laid",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089973",
#                             "label": "n1134",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00004721",
#                                     "taxonomy": "all",
#                                     "label": "van Swinderen B et al., 2001"
#                                 },
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00032201",
#                                     "taxonomy": "all",
#                                     "label": "Ringstad N & Horvitz HR, 2008"
#                                 }
#                             ],
#                             "Remark": [
#                                 "Animals laid more embryos in the one- to eight-cell stage than at the normal 21-cell stage."
#                             ],
#                             "Recessive": "",
#                             "Penetrance": "100% eggs laid are early (e.g. 8 or fewer cells.) (n=38)",
#                             "Variation_effect": [
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Probable null via phenotype",
#                                     "id": "Probable null via phenotype"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Curator_confirmed",
#                                     "id": "Curator_confirmed"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Paper_evidence",
#                                     "id": "Paper_evidence"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": [
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBbt:0006797",
#                                 "label": "oocyte",
#                                 "class": "anatomy_term",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "anatomy-term",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "WBbt:0006797_anatomy-term_abnormal"
#                     },
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBls:0000041",
#                                 "label": "adult Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "life-stage",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "WBls:0000041_life-stage_abnormal"
#                     }
#                 ],
#                 "phenotype": {
#                     "id": "WBPhenotype:0000105",
#                     "label": "oocyte meiotic maturation variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089973",
#                             "label": "n1134",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson2021",
#                                     "label": "Jolene S. Fernandes",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00027739",
#                                     "taxonomy": "all",
#                                     "label": "Govindan JA, Cheng H, Harris JE & Greenstein D, 2006"
#                                 }
#                             ],
#                             "Remark": [
#                                 "Oocytes in mutant females exhibit increased meiotic maturation rates in the absence of sperm"
#                             ],
#                             "Variation_effect": [
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Hypomorph reduction of function",
#                                     "id": "Hypomorph reduction of function"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Curator_confirmed",
#                                     "id": "Curator_confirmed"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Paper_evidence",
#                                     "id": "Paper_evidence"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0001506",
#                     "label": "spontaneous reversal rate variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00248936",
#                             "label": "sy192",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00004721",
#                                     "taxonomy": "all",
#                                     "label": "van Swinderen B et al., 2001"
#                                 }
#                             ],
#                             "Remark": [
#                                 "Animals exhibit an significant increase in spontaneous reversals (~5 backward movements initiated/minute over 2 minutes) (n=27). sy192/+ animals do not exhibit a significant increase in reversals."
#                             ],
#                             "Recessive": ""
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": [
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBbt:0007833",
#                                 "label": "organism",
#                                 "class": "anatomy_term",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "anatomy-term",
#                             "pato_term": "increased sensitivity toward"
#                         },
#                         "key": "WBbt:0007833_anatomy-term_increased sensitivity toward"
#                     }
#                 ],
#                 "phenotype": {
#                     "id": "WBPhenotype:0000016",
#                     "label": "aldicarb hypersensitive",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00242573",
#                             "label": "sa374",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00031872",
#                                     "taxonomy": "all",
#                                     "label": "Vashlishan AB et al., 2008"
#                                 }
#                             ],
#                             "Remark": [
#                                 "% animals paralyzed after 60 min on 1mM aldicarb was significantly higher than % N2 animals paralyzed."
#                             ],
#                             "Affected_by_molecule": [
#                                 {
#                                     "id": "WBMol:00003650",
#                                     "label": "aldicarb",
#                                     "class": "molecule",
#                                     "taxonomy": "all"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0002077",
#                     "label": "dopamine resistant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00604224",
#                             "label": "nd64",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00038270",
#                                     "taxonomy": "all",
#                                     "label": "Allen AT, Maher KN, Wani KA, Betts KE & Chase DL, 2011"
#                                 }
#                             ],
#                             "Remark": [
#                                 "Mutants are resistant to the paralytic effects of dopamine."
#                             ],
#                             "Variation_effect": [
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Probable null via phenotype",
#                                     "id": "Probable null via phenotype"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Curator_confirmed",
#                                     "id": "Curator_confirmed"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Paper_evidence",
#                                     "id": "Paper_evidence"
#                                 }
#                             ],
#                             "Affected_by_molecule": [
#                                 {
#                                     "id": "WBMol:00004583",
#                                     "label": "dopamine",
#                                     "class": "molecule",
#                                     "taxonomy": "all"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000315",
#                     "label": "mechanosensation variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00090649",
#                             "label": "n3055",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson10425",
#                                     "label": "Xiaoyin Chen",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00046308",
#                                     "taxonomy": "all",
#                                     "label": "Chen X, Diaz Cuadros M & Chalfie M, 2015"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000420",
#                     "label": "levamisole hypersensitive",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00242573",
#                             "label": "sa374",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00031872",
#                                     "taxonomy": "all",
#                                     "label": "Vashlishan AB et al., 2008"
#                                 }
#                             ],
#                             "Remark": [
#                                 "% animals paralyzed after 60 min on 200mM levamisole was significantly higher than % N2 animals paralyzed under same conditions."
#                             ],
#                             "Affected_by_molecule": [
#                                 {
#                                     "id": "WBMol:00004019",
#                                     "label": "levamisole",
#                                     "class": "molecule",
#                                     "taxonomy": "all"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0001506",
#                     "label": "spontaneous reversal rate variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089452",
#                             "label": "n363",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00004721",
#                                     "taxonomy": "all",
#                                     "label": "van Swinderen B et al., 2001"
#                                 }
#                             ],
#                             "Remark": [
#                                 "Animals exhibit an significant increase in spontaneous reversals (~4.7 backward movements initiated/minute over 2 minutes) (n=25). n363/+ animals do not exhibit a significant increase in reversals."
#                             ],
#                             "Recessive": "",
#                             "Variation_effect": [
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Null",
#                                     "id": "Null"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Curator_confirmed",
#                                     "id": "Curator_confirmed"
#                                 },
#                                 {
#                                     "taxonomy": "all",
#                                     "class": "tag",
#                                     "label": "Paper_evidence",
#                                     "id": "Paper_evidence"
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000622",
#                     "label": "muscle system development variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089556",
#                             "label": "n499",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Person_evidence": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson261",
#                                     "label": "Jonathan Hodgkin",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Remark": [
#                                 "muscle defective"
#                             ],
#                             "Dominant": "",
#                             "Ease_of_scoring": {
#                                 "taxonomy": "all",
#                                 "class": "tag",
#                                 "label": "Es3 easy to score",
#                                 "id": "Es3 easy to score"
#                             }
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000642",
#                     "label": "hyperactive",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00239182",
#                             "label": "pk39",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Person_evidence": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson261",
#                                     "label": "Jonathan Hodgkin",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Remark": [
#                                 "phenotype similar to sy192"
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000641",
#                     "label": "activity level variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "Allele": {
#                         "text": {
#                             "id": "WBVar00089973",
#                             "label": "n1134",
#                             "class": "variation",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Curator": [
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson461",
#                                     "label": "Daniel Omura",
#                                     "taxonomy": "all"
#                                 },
#                                 {
#                                     "class": "person",
#                                     "id": "WBPerson712",
#                                     "label": "Karen Yook",
#                                     "taxonomy": "all"
#                                 }
#                             ],
#                             "Paper_evidence": [
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00041213",
#                                     "taxonomy": "all",
#                                     "label": "Omura DT, Clark DA, Samuel AD & Horvitz HR, 2012"
#                                 },
#                                 {
#                                     "class": "paper",
#                                     "id": "WBPaper00004721",
# ...
#                                 "label": "Hara Y & Kimura A, 2009"
#                             }
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000760",
#                     "label": "spindle orientation defective early emb",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00081318",
#                             "label": "WBRNAi00081318",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00004811",
#                                 "taxonomy": "all",
#                                 "label": "Zipperlen P, Fraser AG, Kamath RS, Martinez-Campos M & Ahringer J, 2001"
#                             },
#                             "Remark": [
#                                 "The orientation of division of at least one cell in the first three divisions is incorrect."
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000425",
#                     "label": "antibody staining reduced",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00083450",
#                             "label": "WBRNAi00083450",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Genotype": "rrf-1(pk1417);fog-3(q443)",
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00027739",
#                                 "taxonomy": "all",
#                                 "label": "Govindan JA, Cheng H, Harris JE & Greenstein D, 2006"
#                             },
#                             "Remark": [
#                                 "GOA-1 antibody staining reduced specifically in oocytes"
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": [
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBls:0000003",
#                                 "label": "embryo Ce",
#                                 "class": "life_stage",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "life-stage",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "WBls:0000003_life-stage_abnormal"
#                     }
#                 ],
#                 "phenotype": {
#                     "id": "WBPhenotype:0001869",
#                     "label": "meiotic spindle positioning defective",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00079150",
#                             "label": "WBRNAi00079150",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Genotype": "GFP-H2B",
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00032910",
#                                 "taxonomy": "all",
#                                 "label": "van der Voet M et al., 2009"
#                             },
#                             "Remark": [
#                                 "migration of the meiotic spindle to the cell cortex occurs later than wild type"
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000642",
#                     "label": "hyperactive",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00024629",
#                             "label": "WBRNAi00024629",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Genotype": "NL4256 rrf-3(pk1426)",
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00006395",
#                                 "taxonomy": "all",
#                                 "label": "Simmer F et al., 2003"
#                             }
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000417",
#                     "label": "cell division failure",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00063507",
#                             "label": "WBRNAi00063507",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Strain": {
#                                 "id": "WBStrain00000001",
#                                 "label": "N2",
#                                 "class": "strain",
#                                 "taxonomy": "c_elegans"
#                             },
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00005878",
#                                 "taxonomy": "all",
#                                 "label": "Srinivasan DG, Fisk RM, Xu H & van den Heuvel S, 2003"
#                             }
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0000154",
#                     "label": "reduced brood size",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00064318",
#                             "label": "WBRNAi00064318",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Genotype": "rrf-3(pk1426); daf-18(nr2037)",
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00027108",
#                                 "taxonomy": "all",
#                                 "label": "Suzuki Y & Han M, 2006"
#                             },
#                             "Remark": [
#                                 "synthetic phenotype"
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0002074",
#                     "label": "centrosome dynamics variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00114508",
#                             "label": "WBRNAi00114508",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00053799",
#                                 "taxonomy": "all",
#                                 "label": "De Simone A, Spahr A, Busso C & Gonczy P, 2018"
#                             },
#                             "Remark": [
#                                 "Figure 3"
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0002074",
#                     "label": "centrosome dynamics variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00114510",
#                             "label": "WBRNAi00114510",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00049310",
#                                 "taxonomy": "all",
#                                 "label": "De Simone A, Nedelec F & Gonczy P, 2016"
#                             }
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": [
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBbt:0006873",
#                                 "label": "Psub2",
#                                 "class": "anatomy_term",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "anatomy-term",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "WBbt:0006873_anatomy-term_abnormal"
#                     },
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBbt:0006876",
#                                 "label": "EMS",
#                                 "class": "anatomy_term",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "anatomy-term",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "WBbt:0006876_anatomy-term_abnormal"
#                     },
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBbt:0005906",
#                                 "label": "ABa",
#                                 "class": "anatomy_term",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "anatomy-term",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "WBbt:0005906_anatomy-term_abnormal"
#                     },
#                     {
#                         "pato_evidence": {
#                             "entity_term": {
#                                 "id": "WBbt:0005994",
#                                 "label": "ABp",
#                                 "class": "anatomy_term",
#                                 "taxonomy": "all"
#                             },
#                             "entity_type": "anatomy-term",
#                             "pato_term": "abnormal"
#                         },
#                         "key": "WBbt:0005994_anatomy-term_abnormal"
#                     }
#                 ],
#                 "phenotype": {
#                     "id": "WBPhenotype:0001107",
#                     "label": "spindle rotation defective early emb",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00099020",
#                             "label": "WBRNAi00099020",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Genotype": "gpa-16(it143ts); DNC-1::GFP",
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00031420",
#                                 "taxonomy": "all",
#                                 "label": "Zhang H, Skop AR & White JG, 2008"
#                             },
#                             "Remark": [
#                                 "Depletion of two redundant G-alpha proteins, GOA-1 and GPA-16, by RNAi (for goa-1) and use of the gpa-16(it143) temperature sensitive allele resulted in embryos in which the spindle alignments in the anterior daughter cell (ABa) and the posterior daughter cell (ABp) were perturbed. Also, both EMS and P2 spindles failed to rotate to the A-P axis."
#                             ]
#                         }
#                     }
#                 }
#             },
#             {
#                 "entity": null,
#                 "phenotype": {
#                     "id": "WBPhenotype:0001743",
#                     "label": "mitosis variant",
#                     "class": "phenotype",
#                     "taxonomy": "all"
#                 },
#                 "evidence": {
#                     "RNAi": {
#                         "text": {
#                             "id": "WBRNAi00080569",
#                             "label": "WBRNAi00080569",
#                             "class": "rnai",
#                             "taxonomy": "c_elegans"
#                         },
#                         "evidence": {
#                             "Strain": {
#                                 "id": "WBStrain00035144",
#                                 "label": "TY3558",
#                                 "class": "strain",
#                                 "taxonomy": "c_elegans"
#                             },
#                             "Paper_evidence": {
#                                 "class": "paper",
#                                 "id": "WBPaper00024200",
#                                 "taxonomy": "all",
#                                 "label": "Skop AR, Liu H, Yates J, Meyer BJ & Heald R, 2004"
#                             },
#                             "Remark": [
#                                 "The reported phenotype may include cell cycle progression defects and/or spindle defects"
#                             ]
#                         }
#                     }
#                 }
#             }
#         ],
#         "description": "The Phenotype summary of the gene"
#     }
# }

# %% [markdown]
# We output the phenotype ontology in a dataframe which can be used to generate a csv file. If you need any more information to be added in your dataframe, just edit the fields in the cells below as per your requirement!

# %%
#Phenotype Ontology
PO = pd.DataFrame(columns = ['ID', 'Label', 'Taxonomy'])

# %%
phenotype = request.json()['phenotype']['data']
for i in range(len(phenotype)):
    PO = PO.append({'ID' : phenotype[i]['phenotype']['id'], 
                    'Label' : phenotype[i]['phenotype']['label'],
                    'Taxonomy': phenotype[i]['phenotype']['taxonomy']}, ignore_index = True)

# %%
PO
# Out:
#                       ID                                 Label Taxonomy
# 0    WBPhenotype:0000062                                lethal      all
# 1    WBPhenotype:0002292      body posture amplitude decreased      all
# 2    WBPhenotype:0001462    sodium chloride chemotaxis variant      all
# 3    WBPhenotype:0002345            forward locomotion variant      all
# 4    WBPhenotype:0002295     body posture wavelength decreased      all
# ..                   ...                                   ...      ...
# 111  WBPhenotype:0000154                    reduced brood size      all
# 112  WBPhenotype:0002074           centrosome dynamics variant      all
# 113  WBPhenotype:0002074           centrosome dynamics variant      all
# 114  WBPhenotype:0001107  spindle rotation defective early emb      all
# 115  WBPhenotype:0001743                       mitosis variant      all
#
# [116 rows x 3 columns]

# %% [markdown]
# This is the end of the sixth tutorial for WormBase data analysis! This tutorial dealt with obtaining several kinds of ontology information.
#
# In the next tutorial, we will perform Enrichment analyses on WormBase data!
